# %%
from pathlib import Path

from version_flow.clairity_repo import ClairityRepo

repo_dir = Path("~/projects/clarity/auc-report-generator").expanduser()
repo_dir, repo_dir.exists()
# Out:
# (PosixPath('/Users/christianbonnell/projects/clarity/auc-report-generator'),
#  True)

# %%
clrepo = ClairityRepo(repo_dir)

# %%
clrepo.remote_repository_name
# Out:
# 'clairity-inc/auc-report-generator'

# %%
gh_repo = clrepo.get_remote_repo()
gh_repo
# Out:
# Repository(full_name="clairity-inc/auc-report-generator")

# %%
for b in gh_repo.get_branches():
    print(b)
# Out:
# Branch(name="calib-testing-half-preds")
# Branch(name="cjohnson/DA-728-parameterize-current-cancer")
# Branch(name="cjohnson/DA-739-van-calster-bounds")
# Branch(name="cjohnson/DA-739-van-calster-bounds-auc")
# Branch(name="def-response-may2025")
# Branch(name="interactive-report")
# Branch(name="main")
# Branch(name="nbell/da-739-fda-results")
# Branch(name="pvb")
# Branch(name="rc10")
# Branch(name="release")
# Branch(name="rryoung/n_day_cancer_inv")
# Branch(name="ucd-debug")
